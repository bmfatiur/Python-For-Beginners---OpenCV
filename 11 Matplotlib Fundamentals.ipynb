# %% [markdown]
# # Matplotlib
# ## Figure & Axis Creation

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(0, 10, 0.2)
y = np.sin(x)
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(x, y)
plt.savefig("Files/pyplo1.png", dpi=300)

# %%
from pylab import *
x = arange(0, 10, 0.2)
y = sin(x)
plot(x, y)
savefig("pylab1.png", dpi=300)

# %%
fig = plt.figure()
fig.set_size_inches((8.5, 4))

# %%
# single axes - position values are 0-1
left, bottom, width, height = 0.1, 0.2, 0.7, 0.5
ax = fig.add_axes( (left, bottom, width, height) )
ax.plot(x, y)

ax2 = fig.add_axes( (0.9, 0.2, 0.5, 0.2) )
ax2.plot(x, y)
fig

# %%
# 3 axes - 1 row 3 cols (grid)
fig, axes = plt.subplots(1, 3, figsize=(12, 4))
for ax in axes:
    ax.plot(x, y)
    x+=1

# %%
# 1 axes - 1 row 2 cols 2nd position
ax = plt.subplot(122)
ax.plot(x, y)

# %%
x = np.arange(0, 10, 0.2)
y = np.cos(x)
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(x, y, color="r",
       linewidth = 3, linestyle = "--")
fig.savefig(Files/pyplot2.png, dpi=300)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 7
#       3 fig = plt.figure()
#       4 ax = fig.add_subplot(111)
#       5 ax.plot(x, y, color="r",
#       6        linewidth = 3, linestyle = "--")
# ----> 7 fig.savefig(Files/pyplot2.png, dpi=300)
#
# NameError: name 'Files' is not defined
